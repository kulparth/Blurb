# %%
#
# A simple  fun little Blurb -- By Parth
#
class Blurb:
    def __init__(self):
        self.name = 'Parth'
        
        self.domain = ['Data - Big & Small', 'Data Science']
        
        self.industries = ['Finance (FinTech|PropTech)', 
                           'Social Media', 
                           'Ad-Tech',
                           'E-Commerce',
                           'SemiConductor Manufacturing']
        
        self.web_app = 'https://www.dc3rn.com'
        
        self.lang = ['Python',
                     'Pandas',
                     'PySpark',
                     'NodeJS',]
        
        self.os = ['Linux variants']
        
        self.aws = ['S3',
                    'Athena |Presto',
                    'Kinesis',
                    'Glue',
                    'Lambda',
                    'IAM',
                    'EC2',
                    'Cloudwatch',
                    'AWS CLI |SAM',
                    'SNS',
                    'SES',
                    'EMR',
                    '...use as needed']
        
        self.device = ['macbook']
        
        self.editors = ['visual studio code', 
                        'sublime',
                        'atom',
                        'vim',
                        'jupiter-notebook']
        
        self.pkg_mgrs = ['pip', 
                         'conda',
                         'npm']
        
        self.dbs = ['aws-rds|mysql',
                    'ms*sqlserver',
                    'aws-redshift',
                    'mongodb',
                    'oracle',
                    'teradata',
                    'greeeplum']
        
        self.other = ['Hadoop',
                      'Hive',
                      'Docker',
                      'HTML5',
                      'CSS3',
                      'Bootstrap',
                      'Express',
                      'Laravel']
        
        self.repo = ['git']
        
        self.heros = ['Musk', 'Sunder', 'Satya', 'Zuck', 'Systrome', 'Linus', '...many more']
    
    def about(self):
        print("%s's no Neo or Zuck but he codes and re-codes"%(self.name))
        
        print("\n%s's current focus is on %s"%(self.name, self.domain))
        
        print('\n%s worked across industries such as %s'%(self.name,
                                                         self.industries))
        
        print('\nAlthough not a web developer, but %s designed and built a web app %s from the ground up and blogs and shares his learnings. He hosts this app on the Google Cloud Platform (GCP) so he knows a little bit about GCP'%(self.name,
                                                                 self.web_app))
        
        print('\n%s programs in %s on %s'%(self.name,
                                         self.lang, 
                                         self.os))
        
        print('\n%s worked on and uses any of these dbs %s'%(self.name,
                                               self.dbs))
        
        print('\n%s has worked on %s'%(self.name, self.other))
        
        print('\n%s uses aws stack but not limited to it such as %s'%(self.name,
                                      self.aws))
        
        print('\n%s mostly uses %s'%(self.name, self.device))
        
        print('\n%s uses code editors such as %s'%(self.name,
                                                   self.editors))
        
        print('\n%s relies on the elegance of the %s'%(self.name, 
                                                      self.repo))
        
        print('\n%s looks up to heros such as %s'%(self.name, self.heros))
        
        print("\n%s can continue but that won't really be a Blurb"%(self.name))
    
    

pk = Blurb()

pk.about()
# Out:
# Parth's no Neo or Zuck but he codes and re-codes
#
# Parth's current focus is on ['Data - Big & Small', 'Data Science']
#
# Parth worked across industries such as ['Finance (FinTech|PropTech)', 'Social Media', 'Ad-Tech', 'E-Commerce', 'SemiConductor Manufacturing']
#
# Although not a web developer, but Parth designed and built a web app https://www.dc3rn.com from the ground up and blogs and shares his learnings. He hosts this app on the Google Cloud Platform (GCP) so he knows a little bit about GCP
#
# Parth programs in ['Python', 'Pandas', 'PySpark', 'NodeJS'] on ['Linux variants']
#
# Parth worked on and uses any of these dbs ['aws-rds|mysql', 'ms*sqlserver', 'aws-redshift', 'mongodb', 'oracle', 'teradata', 'greeeplum']
#
# Parth has worked on ['Hadoop', 'Hive', 'Docker', 'HTML5', 'CSS3', 'Bootstrap', 'Express', 'Laravel']
#
# ...
